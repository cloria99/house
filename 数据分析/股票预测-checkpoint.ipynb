# %% [markdown]
# # 2.未来预测及相关性分析

# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
#股票数据读取

import pandas_datareader as pdr

# %%
#可视化

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
#时间

from datetime import datetime

# %%
start = datetime(2020,1,1)
mayinglong = pdr.get_data_yahoo("600993.SS",start = start)

# %%
guoyao = pdr.get_data_yahoo("600511.SS",start = start)

# %%
taiji = pdr.get_data_yahoo("600129.SS",start = start)

# %%
jiankangyuan = pdr.get_data_yahoo("600380.SS",start = start)

# %%
mairui = pdr.get_data_yahoo("300760.SZ",start = start) 
mayinglong.head()
# Out:
#              High        Low   Open      Close   Volume  Adj Close
# Date
# 2020-01-02  17.68  17.420000  17.50  17.590000  6722863  17.590000
# 2020-01-03  17.65  17.420000  17.59  17.549999  4613985  17.549999
# 2020-01-06  17.60  17.400000  17.40  17.530001  5191855  17.530001
# 2020-01-07  18.07  17.440001  17.52  18.030001  9749932  18.030001
# 2020-01-08  17.66  17.660000  17.66  17.660000  7091419  17.660000

# %%
mayinglong["Adj Close"].plot(kind="line",legend=True)

# %%
top_tech_df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-226ecb191509> in <module>()
# ----> 1 top_tech_df.plot()
#
# NameError: name 'top_tech_df' is not defined

# %%
#重命名一下，方便设置图例将马应龙、国药、太极集团、健康元数据画在同一张图里，进行对比

mayinglong["myl_Adu Close"]=mayinglong["Adj Close"]
guoyao["gy_Adj Close"] = guoyao["Adj Close"]
taiji["tj_Adj Close"] = taiji["Adj Close"]
jiankangyuan["jky_Adj Close"] = jiankangyuan["Adj Close"]
mairui["mr_Adj Close"] = mairui["Adj Close"]

#对比展示

mayinglong["myl_Adu Close"].plot(legend = True)
guoyao["gy_Adj Close"].plot(legend = True)
taiji["tj_Adj Close"].plot(legend = True)
jiankangyuan["jky_Adj Close"].plot(legend = True)
#mairui["mr_Adj Close"].plot(legend = True)

# %%
mayinglong["myl_Adu Close"]=mayinglong["Adj Close"]
guoyao["gy_Adj Close"] = guoyao["Adj Close"]
taiji["tj_Adj Close"] = taiji["Adj Close"]
jiankangyuan["jky_Adj Close"] = jiankangyuan["Adj Close"]
mairui["mr_Adj Close"] = mairui["Adj Close"]

#对比展示

mayinglong["myl_Adu Close"].plot(legend = True)
guoyao["gy_Adj Close"].plot(legend = True)
taiji["tj_Adj Close"].plot(legend = True)
jiankangyuan["jky_Adj Close"].plot(legend = True)
mairui["mr_Adj Close"].plot(legend = True)

# %%
company = ['600993.SS','600511.SS','600129.SS','600380.SS','300760.SZ']

top_tech_df = pdr.get_data_yahoo(company).
top_tech_df.head()
# Out:
# D:\Program\Anaconda\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: '600993.SS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# D:\Program\Anaconda\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: '600511.SS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# D:\Program\Anaconda\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: '600129.SS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# D:\Program\Anaconda\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: '600380.SS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# D:\Program\Anaconda\lib\site-packages\pandas_datareader\base.py:270: SymbolWarning: Failed to read symbol: '300760.SZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
top_tech_dr = top_tech_df.pct_change()

# %%
top_tech_dr.head()
# Out:
# Attributes Adj Close                                             Close  \
# Symbols    300760.SZ 600129.SS 600380.SS 600511.SS 600993.SS 300760.SZ
# Date
# 2015-06-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-06-30       NaN  0.051777  0.063113  0.028997  0.053857       NaN
# 2015-07-01       NaN -0.077517 -0.100260 -0.100020 -0.082578       NaN
# 2015-07-02       NaN -0.099960 -0.084316 -0.099890 -0.099867       NaN
# 2015-07-03       NaN -0.100000 -0.100078 -0.099951 -0.075847       NaN
#
# Attributes                                            ...         Open  \
# Symbols    600129.SS 600380.SS 600511.SS 600993.SS    ...    300760.SZ
# Date                                                  ...
# 2015-06-29       NaN       NaN       NaN       NaN    ...          NaN
# 2015-06-30  0.051777  0.063113  0.028997  0.053857    ...          NaN
# 2015-07-01 -0.077516 -0.100260 -0.100020 -0.082578    ...          NaN
# ...

# %%
top_tech_df.plot()
plt.xlim("2019-6-1", "2020-6-24")
# Out:
# (737211.0, 737600.0)

# %%
sns.jointplot('600993.SS','600511.SS', top_tech_dr, kind='scatter')
# Out:
# D:\Program\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot('600511.SS','600129.SS', top_tech_dr, kind='scatter')
# Out:
# D:\Program\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(top_tech_dr.dropna())
